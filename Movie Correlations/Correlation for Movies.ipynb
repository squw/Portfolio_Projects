# %%
# This program is to find the correlation between variables in the dataset "movies.csv"


# Imports: 
import pandas as pd
import numpy as np
import seaborn as sns

import re

import matplotlib 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjust the configuration of the plots


# import data frame from "movies.csv"

df = pd.read_csv('movies.csv')

# add index col

for i in range(len(df)):
    df.loc[i, 'index'] = i

# initial length of df

df_len = len(df)

df_len
# Out:
# 7668

# %%
# Observe the data we just imported

df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Detect and delete columns with missing data

df = df.dropna()

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} {}%'.format(col, pct_missing*100))
# Out:
# name 0.0%
# rating 0.0%
# genre 0.0%
# year 0.0%
# released 0.0%
# score 0.0%
# votes 0.0%
# director 0.0%
# writer 0.0%
# star 0.0%
# country 0.0%
# budget 0.0%
# gross 0.0%
# company 0.0%
# runtime 0.0%
# index 0.0%

# %%
# Data types for cols

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# index       float64
# dtype: object

# %%
# Correct cols data type

df['votes'] = df['votes'].astype('int64')

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')
# Out:
# C:\Users\squw-\AppData\Local\Temp\ipykernel_28544\3017036685.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['votes'] = df['votes'].astype('int64')
# C:\Users\squw-\AppData\Local\Temp\ipykernel_28544\3017036685.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['budget'] = df['budget'].astype('int64')
# C:\Users\squw-\AppData\Local\Temp\ipykernel_28544\3017036685.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# since all the deleted columns' preserve their indexes, we need to
#   create an list of number for the next function to loop through

idx_arr = []
for idx in range(df_len):
    try:
        idx_arr.append(df.loc[idx, 'index'])
    except:
        continue

# %%
# Create a corrected year col

for i in idx_arr:
    temp_str = re.split(r"\s+", df.loc[i, 'released'])
    for j in range(len(temp_str)):
        isnum = temp_str[j].isdigit()
        if isnum and len(temp_str[j]) == 4:
            df.loc[i, 'year_corrected'] = temp_str[j]
            break

df
# Out:
# C:\Users\squw-\AppData\Local\Temp\ipykernel_28544\3164391091.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i, 'year_corrected'] = temp_str[j]
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# ...

# %%
df = df.sort_values(by=['gross'],inplace=False, ascending=False)

# %%
# drop any duplicates

df.drop_duplicates()
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
# Scatter plot budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earning')
plt.xlabel('Budget')
plt.ylabel('Gross Earning')

plt.show()

# %%
# Plot budget vs gross using Seaseaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "orange"}, line_kws={"color": "violet"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# looking at correlation:


# methods: pearson(default): a measure of the linear correlation between two sets of numeric data
#          kendall: used to test the similarities in the ordering of data when it is ranked by quantities, it is an alternative to Pearson’s correlation (parametric) when the data you’re working with has failed one or more assumptions of the test. This is also the best alternative to Spearman correlation (non-parametric) when your sample size is small and has many tied ranks.
#          spearman: measures the pearson correlation of the rankings of the variables
df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime     index
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077  0.999522
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068  0.046493
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303  0.192525
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695  0.319194
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796  0.264121
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000  0.067925
# index    0.999522  0.046493  0.192525  0.319194  0.264121  0.067925  1.000000

# %%
# visualize correlation matrix

correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# looks at companies

df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if df_numerized[col_name].dtype == 'object':
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000       952    1683
# 272   2909       6      9  1982      1525    3.9     2300       261      55
# 3203  4966       5      4  1997      2152    5.7     5800       651     161
#
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_numerized.corr()
# Out:
#                     name    rating     genre      year  released     score  \
# name            1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating         -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre           0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year            0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released       -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score           0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes           0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director        0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer          0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star           -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country        -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# ...

# %%
correlation_matrix = df_numerized.corr()

corr_pairs = correlation_matrix.unstack()

corr_pairs
# Out:
# name            name              1.000000
#                 rating           -0.029234
#                 genre             0.010996
#                 year              0.025542
#                 released         -0.006152
#                                     ...
# year_corrected  gross             0.268721
#                 company          -0.018806
#                 runtime           0.075294
#                 index             0.998380
#                 year_corrected    1.000000
# Length: 289, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre           budget           -0.368523
# budget          genre            -0.368523
# genre           gross            -0.244101
# gross           genre            -0.244101
# budget          rating           -0.203946
#                                     ...
# year            year              1.000000
# genre           genre             1.000000
# rating          rating            1.000000
# index           index             1.000000
# year_corrected  year_corrected    1.000000
# Length: 289, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross           votes             0.614751
# votes           gross             0.614751
# budget          gross             0.740247
# gross           budget            0.740247
# index           year_corrected    0.998380
# year_corrected  index             0.998380
#                 year              0.998726
# year            year_corrected    0.998726
#                 index             0.999522
# index           year              0.999522
# name            name              1.000000
# writer          writer            1.000000
# runtime         runtime           1.000000
# company         company           1.000000
# gross           gross             1.000000
# budget          budget            1.000000
# country         country           1.000000
# star            star              1.000000
# director        director          1.000000
# votes           votes             1.000000
# score           score             1.000000
# released        released          1.000000
# ...

# %%
# votes and budges have he highest correlation with gross earning

# company has low correlation with gross earning
